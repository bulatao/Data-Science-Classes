# %% [markdown]
# ## Matplotlib -- plots, histogram, bar charts, pie charts

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
housing_header = ["HomeID", "HomeAge", "HomeSqft", "LotSize", "BedRooms", 
                  "HighSchoolAPI", "ProxFwy", "CarGarage", "ZipCode", "HomePriceK"]

# %%
df = pd.read_csv("fixed-housing-data.csv",names=housing_header)

# %%
df.describe()
# Out:
#            HomeID     HomeAge     HomeSqft      LotSize   BedRooms  \
# count  100.000000  100.000000   100.000000   100.000000  100.00000
# mean    50.500000   17.200000  1615.280000  7840.500000    2.71000
# std     29.011492    4.925711   231.759719  1046.107306    0.71485
# min      1.000000   10.000000  1215.000000  6056.000000    2.00000
# 25%     25.750000   12.750000  1411.500000  7024.250000    2.00000
# 50%     50.500000   17.000000  1606.500000  7822.000000    3.00000
# 75%     75.250000   21.250000  1836.000000  8839.250000    3.00000
# max    100.000000   25.000000  1994.000000  9476.000000    4.00000
#
#        HighSchoolAPI     ProxFwy   CarGarage       ZipCode   HomePriceK
# count     100.000000  100.000000  100.000000    100.000000   100.000000
# mean      904.430000    3.100000    1.520000  94559.250000  1080.990000
# std        36.337713    0.758787    1.234848    475.816351   146.533583
# min       850.000000    2.000000    0.000000  94085.000000   809.000000
# ...

# %%
plt.plot(df.HomePriceK)
plt.show()

# %%
plt.title("LotSize and Price") 
plt.xlabel("LotSize") 
plt.ylabel("HomePriceK") 
plt.scatter(df['LotSize'],df['HomePriceK'])
plt.show()

# %%
plt.title("BedRooms and Price") 
plt.xlabel("BedRooms") 
plt.ylabel("HomePriceK") 
plt.xlim([1,5])
plt.scatter(df['BedRooms'],df['HomePriceK'])

# %%
plt.title("ZipCode and Price") 
plt.xlabel("ZipCode") 
plt.ylabel("HomePriceK") 
plt.scatter(df['ZipCode'],df['HomePriceK'])

# %%
plt.title("ZipCode and Price") 
plt.ylabel("ZipCode") 
plt.xlabel("HomePriceK") 
plt.scatter(df['HomePriceK'],df['ZipCode'])

# %%
plt.figure(1,figsize=(10, 4))

plt.subplot(121) # rows, columns, index or 1 row, 2 columns, 1st graph
plt.title("ZipCode and Price") 
plt.xlabel("ZipCode") 
plt.ylabel("HomePriceK") 
plt.xlim([94080,94090])
plt.scatter(df['ZipCode'],df['HomePriceK'])

plt.subplot(122)
plt.title("ZipCode and Price") 
plt.xlabel("ZipCode") 
plt.ylabel("HomePriceK") 
plt.xlim([95010,95070])
plt.scatter(df['ZipCode'],df['HomePriceK'])

# %%
fig = plt.figure(figsize = (9,9))
ax = fig.gca() # gca = get current axes
df.hist(ax = ax)
# Out:
# C:\Users\sagarwal\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2963: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024FE2ACBF60>,
# ...
#       dtype=object)

# %%
plt.hist(df['HighSchoolAPI'])
plt.show()

# %%
plt.boxplot(df['HomePriceK'])
plt.show()

# %% [markdown]
# # Pyplot tutorial
#
#
# An introduction to the pyplot interface.

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
# Plotting with two lists
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # x, y, ro = red dots
plt.axis([0, 6, 0, 20]) # x-start, x-end, y-start, y-end
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# Plotting with categorical variables
# ===================================
#
# It is also possible to create a plot using categorical variables.
# Matplotlib allows you to pass categorical variables directly to
# many plotting functions. For example:

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(1, figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
def f(t): # some function
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1) # start = 0, end = 5.0, step = 0.1
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211) # it is 2 rows, 1 column, plot 1
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212) # it is 2 rows, 1 column, plot 2
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
mu, sigma = 100, 15 # some distribution
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
# n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)
plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)

plt.xlabel('Stock Price')
plt.ylabel('Probability')
plt.title('Stock Price and Probability')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$') # get scientific characters
plt.axis([40, 160, 0, 0.03]) #xmin,xmax,ymin,ymax
plt.grid(True)
plt.show()

# %% [markdown]
# # Annotating text

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
plt.plot(t, s, lw=2) # line width = 2

plt.annotate('pay attention here', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# In this basic example, both the ``xy`` (arrow tip) and ``xytext``
# locations (text location) are in data coordinates.
#
# Logarithmic and other nonlinear axes
# ====================================
#
# An example of four plots with the same data and different scales for the y axis
# is shown below.

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(121)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

# log
plt.subplot(122)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25, wspace=0.35)
plt.show()

# %% [markdown]
# Subplot example
# ===============
#
# Many plot types can be combined in one figure to create
# powerful and flexible representations of data.

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(20182019)
data = np.random.randn(2, 100)

fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].hist(data[0]) # in the top right corner, locationwise
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])

plt.show()

# %% [markdown]
# ## Bar Charts

# %%
import numpy as np

data = {'Barton LLC': 109438.50,
        'Frami, Hills and Schmidt': 103569.59,
        'Fritsch, Russel and Anderson': 112214.71,
        'Jerde-Hilpert': 112591.43,
        'Keeling LLC': 100934.30,
        'Koepp Ltd': 103660.54,
        'Kulas Inc': 137351.96,
        'Trantow-Barrows': 123381.38,
        'White-Trantow': 135841.99,
        'Will LLC': 104437.60}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
plt.show()

# %%
# Add a vertical line, here we set the style in the function call
fig, ax = plt.subplots() # what is fig?
ax.axvline(group_mean, ls='--', color='r') # overlay a mean value
ax.barh(group_names, group_data)
plt.show()

# %%
fig, ax = plt.subplots()
ax.axvline(group_mean, ls='--', color='r')
ax.set(xlabel='Total Revenue', ylabel='Company', title='Company Revenue')
ax.barh(group_names, group_data)
plt.show()

# %% [markdown]
# # Pie Charts

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig, ax1 = plt.subplots(figsize=(5, 5))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=0)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 15]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
fig, ax1 = plt.subplots(figsize=(5, 5))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Saving the plot
fig.savefig('myPieChart.png')
